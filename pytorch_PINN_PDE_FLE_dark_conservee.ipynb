# %% [markdown]
# # Fokas Lennelles Equation

# %% [markdown]
# $$u_{xt} - u  + 2 i|u|^2u_x=0$$
#
# $x \quad ϵ \quad  [-1,1]$
#
# $t \quad ϵ \quad  [0,1]$

# %% [markdown]
# # New Section

# %% [markdown]
# $$(r +im)_{xt} - (r+im)  + 2 i(r^2 + m^2)(r+im)_x=0$$
# **1. Real part**
# $$r_{xt} - r  -2 (r^2 + m^2)m_x=0$$
# 2. **Imaginary part**
# $$m_{xt} - m  +2 (r^2 + m^2)r_x=0$$

# %% [markdown]
# **Dark Soliton**

# %%
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt


N =100
x_min = -4
x_max = 4
t_min = -1
t_max = 1

x_space = np.linspace(x_min, x_max, N)
t_space = np.linspace(t_min, t_max, N)
x, t = np.meshgrid(x_space, t_space)

k = 1
rho = 1

a = np.sqrt(k**3*rho**2*(1+k*rho**2))
b = k*rho**2


c = k*rho**2/(a**2 +b**2)
theta = a*(x + c*t)
w = 1/k + 2*rho**2



r = rho*( ( (2*a*(a**2 + b**2)*(2*a + (k+b)*np.exp(2 * theta)))*np.cos(k*x - w*t) )-\
(2*a**2*(a**2 + b**2)*np.exp(2*theta) )*np.sin(k*x - w*t)-\
( np.exp(2*theta)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*( 2*a + (k+b)*np.exp(2*theta) ))*np.cos(k*x - w*t)+\
(np.exp(2*theta)*( (k+b)*2*a*b + a*(a**2 - b**2))*( 2*a + (k+b)*np.exp(2*theta) ) )*np.sin(k*x - w*t)+\
(np.exp(2*theta)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*a*np.exp(2*theta) )*np.sin(k*x - w*t)+\
(np.exp(2*theta)*( (k+b)*2*a*b + a*(a**2 - b**2) )*a*np.exp(2*theta))*np.cos(k*x - w*t ) )\
 /( (a**2 + b**2)*( (2*a + (k+b)*np.exp(2*theta) )**2 + a**2*np.exp(4*theta) ) )


m = rho*( ( (2*a*(a**2 + b**2)*(2*a + (k+b)*np.exp(2 * theta)))*np.sin(k*x - w*t) )+\
(2*a**2*(a**2 + b**2)*np.exp(2*theta) )*np.cos(k*x - w*t)-\
( np.exp(2*theta)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*( 2*a + (k+b)*np.exp(2*theta) ))*np.sin(k*x - w*t)-\
(np.exp(2*theta)*( (k+b)*2*a*b + a*(a**2 - b**2))*( 2*a + (k+b)*np.exp(2*theta) ) )*np.cos(k*x - w*t)-\
(np.exp(2*theta)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*a*np.exp(2*theta) )*np.cos(k*x - w*t)+\
(np.exp(2*theta)*( (k+b)*2*a*b + a*(a**2 - b**2) )*a*np.exp(2*theta))*np.sin(k*x - w*t ) )\
 /( (a**2 + b**2)*( (2*a + (k+b)*np.exp(2*theta) )**2 + a**2*np.exp(4*theta) ) )


UU = np.sqrt(r**2 + m**2)

fig = plt.figure(figsize=(8,6))
ax = plt.axes(projection='3d')
ax.plot_surface(x, t, UU, cmap="viridis")
plt.xlabel("x")
plt.ylabel("t")
plt.show()

# %% [markdown]
# PINN to solve PDE

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
torch.manual_seed(123)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
N_0 = 100
N_b = 100
N_r = 2000
np.random.seed(2)

#initial at U(x, t=0)
x_0 = np.random.uniform(low=x_min, high=x_max, size=(N_0, 1))
t_0 = np.ones((N_0, 1), dtype=np.float64)*t_min

theta = a*(x_0 + c*t_min)
# real initial at t=t_min
r_0=rho*( ( (2*a*(a**2 + b**2)*(2*a + (k+b)*np.exp(2 * theta)))*np.cos( k*x_0 - w*t_min ) )-\
(2*a**2*(a**2 + b**2)*np.exp(2*theta) )*np.sin(k*x_0 - w*t_min)-\
( np.exp(2*theta)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*( 2*a + (k+b)*np.exp(2*theta) ))*np.cos(k*x_0 - w*t_min)+\
(np.exp(2*theta)*( (k+b)*2*a*b + a*(a**2 - b**2))*( 2*a + (k+b)*np.exp(2*theta) ) )*np.sin(k*x_0 - w*t_min)+\
(np.exp(2*theta)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*a*np.exp(2*theta) )*np.sin(k*x_0 - w*t_min)+\
(np.exp(2*theta)*( (k+b)*2*a*b + a*(a**2 - b**2) )*a*np.exp(2*theta))*np.cos(k*x_0 - w*t_min ) )\
 /( (a**2 + b**2)*( (2*a + (k+b)*np.exp(2*theta) )**2 + a**2*np.exp(4*theta) ) )


#imaginary
m_0 = rho*( ( (2*a*(a**2 + b**2)*(2*a + (k+b)*np.exp(2 * theta)))*np.sin(k*x_0 - w*t_min) )+\
(2*a**2*(a**2 + b**2)*np.exp(2*theta) )*np.cos(k*x_0 - w*t_min)-\
( np.exp(2*theta)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*( 2*a + (k+b)*np.exp(2*theta) ))*np.sin(k*x_0 - w*t_min)-\
(np.exp(2*theta)*( (k+b)*2*a*b + a*(a**2 - b**2))*( 2*a + (k+b)*np.exp(2*theta) ) )*np.cos(k*x_0 - w*t_min)-\
(np.exp(2*theta)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*a*np.exp(2*theta) )*np.cos(k*x_0 - w*t_min)+\
(np.exp(2*theta)*( (k+b)*2*a*b + a*(a**2 - b**2) )*a*np.exp(2*theta))*np.sin(k*x_0 - w*t_min ) )\
 /( (a**2 + b**2)*( (2*a + (k+b)*np.exp(2*theta) )**2 + a**2*np.exp(4*theta) ) )


# initial condition



t_b1 = np.random.uniform(low=t_min, high=t_max, size=(N_b, 1))
x_b1 = np.ones((N_b, 1), dtype=np.float64)*x_min

#Dirichlet BC left |U|=1
chi1 = k*x_min - w*t_b1
theta1 = a*(x_min + c*t_b1)

#r left
r_left = rho*( ( (2*a*(a**2 + b**2)*(2*a + (k+b)*np.exp(2 * theta1)))*np.cos(chi1) )-\
(2*a**2*(a**2 + b**2)*np.exp(2*theta1) )*np.sin(chi1)-\
( np.exp(2*theta1)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*( 2*a + (k+b)*np.exp(2*theta1) ))*np.cos(chi1)+\
(np.exp(2*theta1)*( (k+b)*2*a*b + a*(a**2 - b**2))*( 2*a + (k+b)*np.exp(2*theta1) ) )*np.sin(chi1)+\
(np.exp(2*theta1)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*a*np.exp(2*theta1) )*np.sin(chi1)+\
(np.exp(2*theta1)*( (k+b)*2*a*b + a*(a**2 - b**2) )*a*np.exp(2*theta1))*np.cos(chi1 ) )\
 /( (a**2 + b**2)*( (2*a + (k+b)*np.exp(2*theta1) )**2 + a**2*np.exp(4*theta1) ) )



# m left
m_left = rho*( ( (2*a*(a**2 + b**2)*(2*a + (k+b)*np.exp(2 * theta1)))*np.sin(chi1) )+\
(2*a**2*(a**2 + b**2)*np.exp(2*theta1) )*np.cos(chi1)-\
( np.exp(2*theta1)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*( 2*a + (k+b)*np.exp(2*theta1) ))*np.sin(chi1)-\
(np.exp(2*theta1)*( (k+b)*2*a*b + a*(a**2 - b**2))*( 2*a + (k+b)*np.exp(2*theta1) ) )*np.cos(chi1)-\
(np.exp(2*theta1)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*a*np.exp(2*theta1) )*np.cos(chi1)+\
(np.exp(2*theta1)*( (k+b)*2*a*b + a*(a**2 - b**2) )*a*np.exp(2*theta1))*np.sin(chi1 ) )\
 /( (a**2 + b**2)*( (2*a + (k+b)*np.exp(2*theta1) )**2 + a**2*np.exp(4*theta1) ) )

#U_b1 = np.ones((N_b, 1), dtype=np.float64)*1.0

t_b2 = np.random.uniform(low=t_min, high=t_max, size=(N_b, 1))
x_b2 = np.ones((N_b, 1), dtype=np.float64)*x_max

chi2 = k*x_max - w*t_b2
theta2 = a*(x_max + c*t_b2)

#r right
r_right = rho*( ( (2*a*(a**2 + b**2)*(2*a + (k+b)*np.exp(2 * theta2)))*np.cos(chi2) )-\
(2*a**2*(a**2 + b**2)*np.exp(2*theta2) )*np.sin(chi2)-\
( np.exp(2*theta2)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*( 2*a + (k+b)*np.exp(2*theta2) ))*np.cos(chi2)+\
(np.exp(2*theta2)*( (k+b)*2*a*b + a*(a**2 - b**2))*( 2*a + (k+b)*np.exp(2*theta2) ) )*np.sin(chi2)+\
(np.exp(2*theta2)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*a*np.exp(2*theta2) )*np.sin(chi2)+\
(np.exp(2*theta2)*( (k+b)*2*a*b + a*(a**2 - b**2) )*a*np.exp(2*theta2))*np.cos(chi2 ) )\
 /( (a**2 + b**2)*( (2*a + (k+b)*np.exp(2*theta2) )**2 + a**2*np.exp(4*theta2) ) )


# m right
m_right = rho*( ( (2*a*(a**2 + b**2)*(2*a + (k+b)*np.exp(2 * theta2)))*np.sin(chi2) )+\
(2*a**2*(a**2 + b**2)*np.exp(2*theta2) )*np.cos(chi2)-\
( np.exp(2*theta2)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*( 2*a + (k+b)*np.exp(2*theta2) ))*np.sin(chi2)-\
(np.exp(2*theta2)*( (k+b)*2*a*b + a*(a**2 - b**2))*( 2*a + (k+b)*np.exp(2*theta2) ) )*np.cos(chi2)-\
(np.exp(2*theta2)*(  (k+b)*(a**2 - b**2) - 2*a**2*b )*a*np.exp(2*theta2) )*np.cos(chi2)+\
(np.exp(2*theta2)*( (k+b)*2*a*b + a*(a**2 - b**2) )*a*np.exp(2*theta2))*np.sin(chi2 ) )\
 /( (a**2 + b**2)*( (2*a + (k+b)*np.exp(2*theta2) )**2 + a**2*np.exp(4*theta2) ) )









#Dirichlet BC
#U_b2 = np.ones((N_b, 1), dtype=np.float64)*1.0


x_c = np.random.uniform(low=x_min, high=x_max, size=(N_r, 1))
t_c = np.random.uniform(low=t_min, high=t_max, size=(N_r, 1))

#x_c1 = np.random.triangular(x_min,-4, x_max, size=(400, 1))
#t_c1 = np.random.triangular(t_min, 0.9, t_max, size=(400, 1))


#x_c = np.vstack((x_c,x_c1))
#t_c = np.vstack((t_c,t_c1))


"""plt.scatter(x_0, r_0)
plt.xlabel("x axis")
plt.ylabel("r")
plt.show()

plt.scatter(x_0, m_0)
plt.xlabel("x axis")
plt.ylabel("m")
plt.show()
plt.scatter(x_0, np.sqrt(m_0**2 + r_0**2))
plt.xlabel("x axis")
plt.ylabel("U")
plt.show()"""

#collocation points
#plt.figure(figsize=(10,4))
plt.scatter(x_b2, t_b2, marker='x')
plt.scatter(x_b1, t_b1, marker='x')
plt.scatter(x_0, t_0, marker='p')
plt.scatter(x_c, t_c, s=0.8)
plt.xlabel("x axis")
plt.ylabel("t axis")

plt.savefig("collocationn_gaussian.png", dpi='figure', transparent = True)
plt.title("collocation point")
plt.show()


"""#collocation points
#plt.scatter(x_b2, t_b2, marker='x')
#plt.scatter(x_b1, t_b1, marker='x')
#plt.scatter(x_0, t_0, marker='p')
plt.scatter(np.vstack((x_c, x_c1)), np.vstack((t_c, t_c1)), s=0.8)
plt.xlabel("x axis")
plt.ylabel("t axis")

plt.savefig("collocationn_triangular.png", dpi='figure', transparent = True)
plt.title("collocation point")
plt.show()"""
# Out:
# '#collocation points\n#plt.scatter(x_b2, t_b2, marker=\'x\')\n#plt.scatter(x_b1, t_b1, marker=\'x\')\n#plt.scatter(x_0, t_0, marker=\'p\')\nplt.scatter(np.vstack((x_c, x_c1)), np.vstack((t_c, t_c1)), s=0.8)\nplt.xlabel("x axis")\nplt.ylabel("t axis")\n\nplt.savefig("collocationn_triangular.png", dpi=\'figure\', transparent = True)\nplt.title("collocation point")\nplt.show()'

# %% [markdown]
# #Neural Network

# %% [markdown]
# ## We consider Neural Network as our solution u(x,t)

# %%
class Neural_network(nn.Module):
  def __init__(self):
    super(Neural_network, self).__init__()
    self.input_layer = nn.Linear(2,60)

    #self.dropout = nn.Dropout(0.25)
    self.hidden_layer1 = nn.Linear(60,60)
    self.hidden_layer2 = nn.Linear(60,60)
    self.hidden_layer3 = nn.Linear(60,60)
    self.hidden_layer4 = nn.Linear(60,60)
    self.hidden_layer5 = nn.Linear(60,60)
    self.hidden_layer6 = nn.Linear(60,60)
    self.hidden_layer7 = nn.Linear(60,60)
    self.hidden_layer8 = nn.Linear(60,60)
    self.output_layer = nn.Linear(60,2)

  def morlet(self, x):
    return torch.cos(7/4 *x)*torch.exp((-x**2)/2)
  def maxican(self, x):
    return (1 - x**2)*torch.exp((-x**2)/2)
  def gause(self, x):
    return (- x)*torch.exp((-x**2)/2)
  def tanh_2(self,x):
    return torch.tanh(x)**2


  def forward(self, x):

    x = self.input_layer(x)
    x = torch.tanh(x)
    x = torch.tanh(self.hidden_layer1(x))
    x = torch.tanh(self.hidden_layer2(x))

    #x = self.dropout(x)
    x = torch.tanh(self.hidden_layer3(x))
    x = torch.tanh(self.hidden_layer4(x))
    x = torch.tanh(self.hidden_layer5(x))
    x = torch.tanh(self.hidden_layer6(x))
    x = torch.tanh(self.hidden_layer7(x))
    x = torch.tanh(self.hidden_layer8(x))
    x = self.output_layer(x)
    return x

# %%
Net = Neural_network()
Net = Net.to(device)
loss_fu = nn.MSELoss()
optim = torch.optim.Adam(Net.parameters(), lr=0.001)

#scheduler = torch.optim.lr_scheduler.MultiStepLR(optim, milestones=[20000,30000], gamma=0.1)

# %%
#initail
x_01 = torch.autograd.Variable( torch.from_numpy(x_0).float(), requires_grad=False).to(device)
t_01 = torch.autograd.Variable( torch.from_numpy(t_0).float(), requires_grad=False).to(device)
R_01 = torch.autograd.Variable( torch.from_numpy(r_0).float(), requires_grad=False).to(device)
M_01 = torch.autograd.Variable( torch.from_numpy(m_0).float(), requires_grad=False).to(device)
X_0 = torch.cat([x_01, t_01], axis=1)

#BC1
x_b11 = torch.autograd.Variable( torch.from_numpy(x_b1).float(), requires_grad=True).to(device)
t_b11 = torch.autograd.Variable( torch.from_numpy(t_b1).float(), requires_grad=False).to(device)
R_left = torch.autograd.Variable( torch.from_numpy(r_left).float(), requires_grad=False).to(device)
M_left = torch.autograd.Variable( torch.from_numpy(m_left).float(), requires_grad=False).to(device)

X_b1 = torch.cat([x_b11, t_b11], axis=1)

#BC2
x_b21 = torch.autograd.Variable( torch.from_numpy(x_b2).float(), requires_grad=True).to(device)
t_b21 = torch.autograd.Variable( torch.from_numpy(t_b2).float(), requires_grad=False).to(device)
R_right = torch.autograd.Variable( torch.from_numpy(r_right).float(), requires_grad=False).to(device)
M_right = torch.autograd.Variable( torch.from_numpy(m_right).float(), requires_grad=False).to(device)
X_b2 = torch.cat([x_b21, t_b21], axis=1)



U_b1 = np.ones((N_b, 1), dtype=np.float64)*1.0
U_b11 = torch.autograd.Variable( torch.from_numpy(U_b1).float(), requires_grad=False).to(device)

# %% [markdown]
# # PDE Loss

# %%
def pde(x, t, Net):
  x_1 = torch.autograd.Variable( torch.from_numpy(x).float(), requires_grad=True).to(device)
  t_1 = torch.autograd.Variable( torch.from_numpy(t).float(), requires_grad=True).to(device)
  X = torch.cat([x_1, t_1], axis=1)

  rr = Net.forward(X)[:, 0:1]
  mm = Net.forward(X)[:, 1:2]

  r_x = torch.autograd.grad(rr.sum(), x_1, create_graph=True)[0]
  r_xx = torch.autograd.grad(r_x.sum(), x_1, create_graph=True)[0]
  r_xxx = torch.autograd.grad(r_xx.sum(), x_1, create_graph=True)[0]
  r_t = torch.autograd.grad(rr.sum(), t_1, create_graph=True)[0]
  r_xt = torch.autograd.grad(r_t.sum(), x_1, create_graph=True)[0]

  m_x = torch.autograd.grad(mm.sum(), x_1, create_graph=True)[0]
  m_xx = torch.autograd.grad(m_x.sum(), x_1, create_graph=True)[0]
  m_xxx = torch.autograd.grad(m_xx.sum(), x_1, create_graph=True)[0]
  m_t = torch.autograd.grad(mm.sum(), t_1, create_graph=True)[0]
  m_xt = torch.autograd.grad(m_t.sum(), x_1, create_graph=True)[0]


  pde1 = r_xt - rr - 2*(rr**2 + mm**2)*m_x
  pde2 = m_xt - mm  + 2*(rr**2 + mm**2)*r_x


  #H1 = integrate (r_x**2 + m_x**2) dx

  def integral_approximation(f, aa):
    return (aa.max() - aa.min() )*torch.mean(f)


  # H1
  H = (r_x**2 + m_x**2)
  H1 = integral_approximation(H, x_1 )
  H1_t = torch.autograd.grad(H1.sum(), t_1, create_graph=True)[0]

  #H3
  H3_real = (r_x**2 + m_x**2)**2 - r_xx*m_x + r_x*m_xx
  H3_imag = -(r_x*r_xx + m_x*m_xx)

  H3_real_integrate = integral_approximation(H3_real, x_1 )
  H3_imag_integrate = integral_approximation(H3_imag, x_1 )

  H3r_t = torch.autograd.grad(H3_real_integrate.sum() , t_1, create_graph=True)[0]
  H3m_t = torch.autograd.grad(H3_imag_integrate.sum() , t_1, create_graph=True)[0]

  #H5
  H5_real = -(r_x*r_xxx + m_x*m_xxx) + 2*(r_x**2 + m_x**2)**3 + 3*(r_x**2 + m_x**2)*(r_x*m_xx -r_xx*m_x)
  H5_imag = -(-r_xxx*m_x + r_x*m_xxx) - 3*(r_x**2 + m_x**2)*(r_x*r_xx + m_x*m_xx)

  H5_real_integrate = integral_approximation(H5_real, x_1 )
  H5_imag_integrate = integral_approximation(H5_imag, x_1 )

  H5r_t = torch.autograd.grad(H5_real_integrate.sum() , t_1, create_graph=True)[0]
  H5m_t = torch.autograd.grad(H5_imag_integrate.sum() , t_1, create_graph=True)[0]

  #H-1
  H11_real = -rr*m_x + r_x*mm
  H11_imag = -r_x*rr - mm*m_x

  H11_real_integrate = integral_approximation(H11_real, x_1 )
  H11_imag_integrate = integral_approximation(H11_imag, x_1 )

  H11r_t = torch.autograd.grad(H11_real_integrate.sum() , t_1, create_graph=True)[0]
  H11m_t = torch.autograd.grad(H11_imag_integrate.sum(), t_1, create_graph=True)[0]

  #H-3
  H33_real = -(rr**2 + mm**2) - (rr**2+mm**2)*(rr*m_x - r_x*mm)
  H33_imag = -(rr**2 + mm**2)*(rr*r_x + mm*m_x)

  H33_real_integrate = integral_approximation(H33_real, x_1 )
  H33_imag_integrate = integral_approximation(H33_imag, x_1 )

  H33r_t = torch.autograd.grad(H33_real_integrate.sum() , t_1, create_graph=True)[0]
  H33m_t = torch.autograd.grad(H33_imag_integrate.sum(), t_1, create_graph=True)[0]





  return pde1, pde2, H1_t, H3r_t, H3m_t, H5r_t, H5m_t, H11r_t, H11m_t, H33r_t, H33m_t

# %% [markdown]
# #Loss

# %%
number_of_epoch =30000
loss_value = []
loss_value1 = []
loss_value2 = []
loss_value3 = []
for epoch in range(number_of_epoch):
  optim.zero_grad()       # make the gradient zero

  r_pred_0, m_pred_0  = Net.forward(X_0)[:, 0:1], Net.forward(X_0)[:, 1:2]      #forward pass
  Loss_initial = loss_fu(r_pred_0, R_01 ) + loss_fu(m_pred_0, M_01 )    # loss of initial

  r_pred_b1, m_pred_b1 = Net.forward(X_b1)[:, 0:1], Net.forward(X_b1)[:, 1:2]
  Loss_b1 = loss_fu( r_pred_b1, R_left) + loss_fu(m_pred_b1, M_left)             # left boudary loss

  Loss_b1_new = loss_fu( (r_pred_b1**2 + m_pred_b1**2), U_b11)

  r_pred_b2, m_pred_b2 = Net.forward(X_b2)[:, 0:1], Net.forward(X_b2)[:, 1:2]
  Loss_b2 = loss_fu( r_pred_b2, R_right) + loss_fu(m_pred_b2, M_right)            #right boundary loss

  Loss_b2_new = loss_fu( (r_pred_b2**2 + m_pred_b2**2), U_b11)

  r_pred_b1_x = torch.autograd.grad(r_pred_b1.sum(), x_b11, create_graph=True)[0]
  m_pred_b1_x = torch.autograd.grad(m_pred_b1.sum(), x_b11, create_graph=True)[0]

  r_pred_b2_x = torch.autograd.grad(r_pred_b2.sum(), x_b21, create_graph=True)[0]
  m_pred_b2_x = torch.autograd.grad(m_pred_b2.sum(), x_b21, create_graph=True)[0]

  loss_b3 = loss_fu(r_pred_b1_x, r_pred_b2_x)
  loss_b4 = loss_fu(m_pred_b1_x, m_pred_b2_x)


  pdee1, pdee2, H1_t, H3r_t, H3m_t, H5r_t, H5m_t, H11r_t, H11m_t, H33r_t, H33m_t= pde(x_c, t_c, Net)                # pde losss
  Loss_pde = torch.linalg.norm(pdee1) + torch.linalg.norm(pdee2)

  Loss_conserve1 = torch.linalg.norm(H1_t)
  Loss_conserve3 = torch.linalg.norm(H3r_t) + torch.linalg.norm(H3m_t)
  Loss_conserve5 = torch.linalg.norm(H5r_t) + torch.linalg.norm(H5m_t)
  Loss_conserve11 = 2*(torch.linalg.norm(H11r_t) + torch.linalg.norm(H11m_t))
  Loss_conserve33 = torch.linalg.norm(H33r_t) + torch.linalg.norm(H33m_t)








  total_loss =  (Loss_initial +  Loss_b1 + Loss_b2)   +  0.001*( Loss_pde) + 0.001*(Loss_conserve33 )#+ Loss_conserve33)\
                    #Loss_conserve1 + Loss_conserve3 + Loss_conserve5 + )  #+ loss_b3 + loss_b4

  total_loss.backward()    # computing gradients using backward propagation  dL/dw
  optim.step()             # This is equivalent to : Weight_new = weight_old - learing_rate * derivative of Loss w.r.t weight
  #scheduler.step()

  loss_value.append(total_loss.cpu().detach().numpy())
  loss_value1.append(Loss_conserve1.cpu().detach().numpy())
  loss_value3.append(Loss_conserve3.cpu().detach().numpy())

  loss_value2.append(Loss_pde.cpu().detach().numpy())
  with torch.autograd.no_grad():
    if epoch%100==0:
      print(f'epoch:{epoch}, loss:{total_loss.item():.8f}, Loss_conserve1:{Loss_conserve1.item():.8f},Loss_conserve3:{Loss_conserve3.item():.8f}, Loss_pde:{Loss_pde.item():.8f}')

plt.plot(loss_value)
plt.show()
plt.plot(loss_value1)
plt.show()
plt.plot(loss_value2)
plt.show()
# Out:
# epoch:0, loss:2.93508601, Loss_conserve1:0.00000025,Loss_conserve3:0.00000032, Loss_pde:2.88055038
# epoch:100, loss:0.30770659, Loss_conserve1:0.25645754,Loss_conserve3:1.28296924, Loss_pde:103.60292816
# epoch:200, loss:0.17556049, Loss_conserve1:0.11902869,Loss_conserve3:0.36497313, Loss_pde:79.93937683
# epoch:300, loss:0.10932784, Loss_conserve1:0.11460010,Loss_conserve3:0.35044178, Loss_pde:73.90457916
# epoch:400, loss:0.10357826, Loss_conserve1:0.11083250,Loss_conserve3:0.33087945, Loss_pde:71.00178528
# epoch:500, loss:0.07390248, Loss_conserve1:0.10834435,Loss_conserve3:0.31945372, Loss_pde:68.06397247
# epoch:600, loss:0.07075153, Loss_conserve1:0.10758065,Loss_conserve3:0.31376743, Loss_pde:65.87581635
# epoch:700, loss:0.06784971, Loss_conserve1:0.10700928,Loss_conserve3:0.30838853, Loss_pde:63.65586853
# epoch:800, loss:0.06498139, Loss_conserve1:0.10683116,Loss_conserve3:0.30020952, Loss_pde:60.82830048
# epoch:900, loss:0.06109790, Loss_conserve1:0.10574753,Loss_conserve3:0.28807828, Loss_pde:57.68825531
# epoch:1000, loss:0.05815492, Loss_conserve1:0.10497754,Loss_conserve3:0.27999228, Loss_pde:54.92562103
# epoch:1100, loss:0.05423043, Loss_conserve1:0.10217439,Loss_conserve3:0.27166548, Loss_pde:50.99694824
# epoch:1200, loss:0.05209338, Loss_conserve1:0.09920350,Loss_conserve3:0.26233900, Loss_pde:49.18740845
# epoch:1300, loss:0.04815136, Loss_conserve1:0.10104781,Loss_conserve3:0.26757309, Loss_pde:45.98085022
# epoch:1400, loss:0.04668139, Loss_conserve1:0.09911562,Loss_conserve3:0.26266265, Loss_pde:44.73496246
# epoch:1500, loss:0.04497819, Loss_conserve1:0.09611154,Loss_conserve3:0.25019220, Loss_pde:43.23830414
# epoch:1600, loss:0.04500703, Loss_conserve1:0.09227940,Loss_conserve3:0.24201453, Loss_pde:42.27638245
# epoch:1700, loss:0.04176616, Loss_conserve1:0.08802152,Loss_conserve3:0.22951135, Loss_pde:40.13514709
# epoch:1800, loss:0.03970283, Loss_conserve1:0.08396163,Loss_conserve3:0.22530493, Loss_pde:38.00331116
# epoch:1900, loss:0.03765111, Loss_conserve1:0.07848357,Loss_conserve3:0.22884534, Loss_pde:35.05551529
# epoch:2000, loss:0.04422525, Loss_conserve1:0.07507984,Loss_conserve3:0.26586503, Loss_pde:29.00033760
# epoch:2100, loss:0.02529423, Loss_conserve1:0.07431963,Loss_conserve3:0.37694442, Loss_pde:23.68388748
# epoch:2200, loss:0.03387461, Loss_conserve1:0.06682009,Loss_conserve3:0.31515688, Loss_pde:23.60936356
# epoch:2300, loss:0.02334075, Loss_conserve1:0.06237217,Loss_conserve3:0.28493699, Loss_pde:20.56155014
# epoch:2400, loss:0.03037599, Loss_conserve1:0.05878131,Loss_conserve3:0.25506479, Loss_pde:21.09710312
# epoch:2500, loss:0.02232642, Loss_conserve1:0.05373998,Loss_conserve3:0.22103965, Loss_pde:18.77479935
# epoch:2600, loss:0.01946203, Loss_conserve1:0.04991450,Loss_conserve3:0.19906919, Loss_pde:17.29229546
# epoch:2700, loss:0.01804382, Loss_conserve1:0.04655896,Loss_conserve3:0.17895900, Loss_pde:16.17204857
# epoch:2800, loss:0.01875346, Loss_conserve1:0.04318573,Loss_conserve3:0.16233611, Loss_pde:15.51075172
# epoch:2900, loss:0.02040907, Loss_conserve1:0.04007509,Loss_conserve3:0.14952923, Loss_pde:15.58585358
# epoch:3000, loss:0.01793014, Loss_conserve1:0.03737599,Loss_conserve3:0.14119887, Loss_pde:13.82514191
# epoch:3100, loss:0.01546980, Loss_conserve1:0.03419974,Loss_conserve3:0.12862679, Loss_pde:12.36954689
# epoch:3200, loss:0.01418476, Loss_conserve1:0.03094531,Loss_conserve3:0.12047146, Loss_pde:11.23610020
# epoch:3300, loss:0.01464780, Loss_conserve1:0.02856485,Loss_conserve3:0.11594042, Loss_pde:10.46061993
# epoch:3400, loss:0.01276187, Loss_conserve1:0.02648094,Loss_conserve3:0.11098903, Loss_pde:9.54797935
# epoch:3500, loss:0.01144936, Loss_conserve1:0.02461206,Loss_conserve3:0.10521916, Loss_pde:8.55318642
# epoch:3600, loss:0.01117431, Loss_conserve1:0.02294629,Loss_conserve3:0.10133053, Loss_pde:7.44701099
# epoch:3700, loss:0.00929887, Loss_conserve1:0.02183825,Loss_conserve3:0.09568674, Loss_pde:7.00456429
# epoch:3800, loss:0.00891983, Loss_conserve1:0.02080293,Loss_conserve3:0.09003899, Loss_pde:6.53130007
# epoch:3900, loss:0.01234035, Loss_conserve1:0.02004537,Loss_conserve3:0.09020461, Loss_pde:6.22707844
# epoch:4000, loss:0.00937136, Loss_conserve1:0.01978649,Loss_conserve3:0.08710919, Loss_pde:5.84686661
# epoch:4100, loss:0.00875777, Loss_conserve1:0.01936218,Loss_conserve3:0.08507890, Loss_pde:5.54121923
# epoch:4200, loss:0.00701008, Loss_conserve1:0.01941080,Loss_conserve3:0.08159588, Loss_pde:5.32699966
# epoch:4300, loss:0.01010116, Loss_conserve1:0.01901641,Loss_conserve3:0.08299318, Loss_pde:5.26803398
# epoch:4400, loss:0.00651543, Loss_conserve1:0.01883752,Loss_conserve3:0.07902205, Loss_pde:4.99850225
# epoch:4500, loss:0.00728290, Loss_conserve1:0.01881083,Loss_conserve3:0.07832555, Loss_pde:4.82633495
# epoch:4600, loss:0.00595336, Loss_conserve1:0.01874040,Loss_conserve3:0.07636447, Loss_pde:4.61791325
# epoch:4700, loss:0.00614377, Loss_conserve1:0.01870276,Loss_conserve3:0.07520998, Loss_pde:4.60055447
# epoch:4800, loss:0.00560363, Loss_conserve1:0.01847939,Loss_conserve3:0.07405704, Loss_pde:4.35373878
# epoch:4900, loss:0.00759241, Loss_conserve1:0.01868112,Loss_conserve3:0.07576132, Loss_pde:4.41311646
# epoch:5000, loss:0.00566962, Loss_conserve1:0.01845042,Loss_conserve3:0.07145383, Loss_pde:4.26629972
# epoch:5100, loss:0.00533378, Loss_conserve1:0.01860337,Loss_conserve3:0.07183103, Loss_pde:4.17685080
# epoch:5200, loss:0.00533409, Loss_conserve1:0.01856832,Loss_conserve3:0.07149041, Loss_pde:4.10409880
# epoch:5300, loss:0.00499679, Loss_conserve1:0.01868636,Loss_conserve3:0.07276787, Loss_pde:3.94961381
# epoch:5400, loss:0.00661972, Loss_conserve1:0.01874646,Loss_conserve3:0.07455757, Loss_pde:3.89933062
# epoch:5500, loss:0.00480440, Loss_conserve1:0.01889362,Loss_conserve3:0.07323603, Loss_pde:3.77912402
# epoch:5600, loss:0.00537706, Loss_conserve1:0.01862433,Loss_conserve3:0.07284396, Loss_pde:3.66332817
# epoch:5700, loss:0.00488922, Loss_conserve1:0.01870408,Loss_conserve3:0.07280483, Loss_pde:3.63827467
# epoch:5800, loss:0.00603504, Loss_conserve1:0.01942467,Loss_conserve3:0.07283095, Loss_pde:3.95401192
# epoch:5900, loss:0.00525912, Loss_conserve1:0.01918785,Loss_conserve3:0.07257111, Loss_pde:3.90397215
# epoch:6000, loss:0.00471180, Loss_conserve1:0.01924306,Loss_conserve3:0.07331212, Loss_pde:3.85701895
# epoch:6100, loss:0.00458838, Loss_conserve1:0.01944484,Loss_conserve3:0.07424308, Loss_pde:3.68492079
# epoch:6200, loss:0.00470259, Loss_conserve1:0.01934378,Loss_conserve3:0.07344285, Loss_pde:3.78448296
# epoch:6300, loss:0.00545964, Loss_conserve1:0.01958129,Loss_conserve3:0.07312696, Loss_pde:3.82147455
# epoch:6400, loss:0.00483873, Loss_conserve1:0.01952864,Loss_conserve3:0.07511234, Loss_pde:3.42311478
# epoch:6500, loss:0.00429682, Loss_conserve1:0.01933634,Loss_conserve3:0.07392154, Loss_pde:3.46216726
# epoch:6600, loss:0.00415484, Loss_conserve1:0.01926489,Loss_conserve3:0.07372835, Loss_pde:3.24548125
# epoch:6700, loss:0.00443942, Loss_conserve1:0.01973448,Loss_conserve3:0.07559189, Loss_pde:3.52718139
# epoch:6800, loss:0.00578942, Loss_conserve1:0.01975574,Loss_conserve3:0.07396793, Loss_pde:3.66267657
# epoch:6900, loss:0.00476081, Loss_conserve1:0.02013785,Loss_conserve3:0.07566535, Loss_pde:3.63423562
# epoch:7000, loss:0.00521082, Loss_conserve1:0.02020981,Loss_conserve3:0.07597050, Loss_pde:3.63962507
# epoch:7100, loss:0.00407064, Loss_conserve1:0.01974017,Loss_conserve3:0.07565616, Loss_pde:3.11226797
# epoch:7200, loss:0.00421849, Loss_conserve1:0.02025835,Loss_conserve3:0.07665185, Loss_pde:3.40793920
# epoch:7300, loss:0.00484449, Loss_conserve1:0.02020226,Loss_conserve3:0.07601526, Loss_pde:3.51601505
# epoch:7400, loss:0.00428634, Loss_conserve1:0.02040910,Loss_conserve3:0.07751837, Loss_pde:3.49667549
# epoch:7500, loss:0.00437138, Loss_conserve1:0.02009789,Loss_conserve3:0.07754490, Loss_pde:3.08919859
# epoch:7600, loss:0.00396592, Loss_conserve1:0.02001476,Loss_conserve3:0.07683060, Loss_pde:3.04784846
# epoch:7700, loss:0.00388261, Loss_conserve1:0.02037797,Loss_conserve3:0.07783673, Loss_pde:3.13007164
# epoch:7800, loss:0.00763613, Loss_conserve1:0.02028972,Loss_conserve3:0.07663468, Loss_pde:3.54920149
# epoch:7900, loss:0.00416788, Loss_conserve1:0.02059985,Loss_conserve3:0.07830631, Loss_pde:3.38039351
# epoch:8000, loss:0.00385952, Loss_conserve1:0.02043995,Loss_conserve3:0.07845158, Loss_pde:3.05619621
# epoch:8100, loss:0.00424793, Loss_conserve1:0.02057084,Loss_conserve3:0.07927860, Loss_pde:2.98708344
# epoch:8200, loss:0.00383380, Loss_conserve1:0.02096700,Loss_conserve3:0.07979394, Loss_pde:3.13721085
# epoch:8300, loss:0.00574416, Loss_conserve1:0.02080602,Loss_conserve3:0.08103727, Loss_pde:3.01841593
# epoch:8400, loss:0.00512898, Loss_conserve1:0.02068502,Loss_conserve3:0.07805629, Loss_pde:3.38247967
# epoch:8500, loss:0.00500361, Loss_conserve1:0.02080053,Loss_conserve3:0.08036362, Loss_pde:2.91283846
# epoch:8600, loss:0.00496473, Loss_conserve1:0.02098789,Loss_conserve3:0.07885594, Loss_pde:3.28117561
# epoch:8700, loss:0.00405117, Loss_conserve1:0.02098606,Loss_conserve3:0.07966949, Loss_pde:3.23488045
# epoch:8800, loss:0.00382839, Loss_conserve1:0.02087508,Loss_conserve3:0.07995086, Loss_pde:3.01494360
# epoch:8900, loss:0.00371568, Loss_conserve1:0.02116538,Loss_conserve3:0.08092756, Loss_pde:2.96461940
# epoch:9000, loss:0.00410267, Loss_conserve1:0.02125289,Loss_conserve3:0.08058955, Loss_pde:3.17139482
# epoch:9100, loss:0.00414725, Loss_conserve1:0.02127438,Loss_conserve3:0.08132635, Loss_pde:2.88990855
# epoch:9200, loss:0.00363577, Loss_conserve1:0.02123975,Loss_conserve3:0.08095708, Loss_pde:2.97384143
# epoch:9300, loss:0.00466057, Loss_conserve1:0.02135206,Loss_conserve3:0.08039199, Loss_pde:3.16593266
# epoch:9400, loss:0.00430099, Loss_conserve1:0.02109749,Loss_conserve3:0.08244947, Loss_pde:2.79235220
# epoch:9500, loss:0.00390088, Loss_conserve1:0.02101509,Loss_conserve3:0.08006229, Loss_pde:2.95701766
# epoch:9600, loss:0.00524004, Loss_conserve1:0.02154221,Loss_conserve3:0.08378706, Loss_pde:2.89884949
# epoch:9700, loss:0.00468605, Loss_conserve1:0.02125392,Loss_conserve3:0.08324389, Loss_pde:2.82732964
# epoch:9800, loss:0.00357422, Loss_conserve1:0.02121119,Loss_conserve3:0.08108330, Loss_pde:2.83571720
# epoch:9900, loss:0.00387526, Loss_conserve1:0.02119066,Loss_conserve3:0.08062272, Loss_pde:2.98259330
# epoch:10000, loss:0.00416227, Loss_conserve1:0.02138390,Loss_conserve3:0.08285435, Loss_pde:2.77994037
# epoch:10100, loss:0.00337542, Loss_conserve1:0.02157109,Loss_conserve3:0.08244191, Loss_pde:2.80144358
# epoch:10200, loss:0.00376676, Loss_conserve1:0.02178835,Loss_conserve3:0.08247782, Loss_pde:3.03338242
# epoch:10300, loss:0.00357429, Loss_conserve1:0.02186550,Loss_conserve3:0.08331539, Loss_pde:2.88569975
# epoch:10400, loss:0.00374955, Loss_conserve1:0.02181370,Loss_conserve3:0.08340412, Loss_pde:2.71792269
# epoch:10500, loss:0.00475207, Loss_conserve1:0.02167185,Loss_conserve3:0.08174948, Loss_pde:2.92080641
# epoch:10600, loss:0.00417836, Loss_conserve1:0.02169371,Loss_conserve3:0.08404803, Loss_pde:2.67937851
# epoch:10700, loss:0.00376066, Loss_conserve1:0.02187095,Loss_conserve3:0.08266444, Loss_pde:2.87748098
# epoch:10800, loss:0.00354202, Loss_conserve1:0.02165089,Loss_conserve3:0.08404908, Loss_pde:2.68333006
# epoch:10900, loss:0.00362132, Loss_conserve1:0.02179981,Loss_conserve3:0.08279560, Loss_pde:2.94100475
# epoch:11000, loss:0.00454739, Loss_conserve1:0.02132206,Loss_conserve3:0.08091213, Loss_pde:3.00259352
# epoch:11100, loss:0.00390805, Loss_conserve1:0.02195200,Loss_conserve3:0.08269262, Loss_pde:2.91028404
# epoch:11200, loss:0.00391869, Loss_conserve1:0.02181334,Loss_conserve3:0.08237012, Loss_pde:2.88937998
# epoch:11300, loss:0.00362390, Loss_conserve1:0.02165838,Loss_conserve3:0.08267759, Loss_pde:2.89658356
# epoch:11400, loss:0.00327430, Loss_conserve1:0.02215248,Loss_conserve3:0.08446065, Loss_pde:2.65962386
# epoch:11500, loss:0.00352173, Loss_conserve1:0.02183259,Loss_conserve3:0.08440083, Loss_pde:2.61037540
# epoch:11600, loss:0.00343321, Loss_conserve1:0.02214064,Loss_conserve3:0.08599387, Loss_pde:2.75351334
# epoch:11700, loss:0.00322535, Loss_conserve1:0.02193066,Loss_conserve3:0.08398890, Loss_pde:2.69946051
# epoch:11800, loss:0.00387591, Loss_conserve1:0.02189005,Loss_conserve3:0.08274867, Loss_pde:2.86077118
# epoch:11900, loss:0.00494379, Loss_conserve1:0.02167627,Loss_conserve3:0.08140413, Loss_pde:2.72331524
# epoch:12000, loss:0.00512864, Loss_conserve1:0.02203716,Loss_conserve3:0.08826944, Loss_pde:2.63340569
# epoch:12100, loss:0.00448756, Loss_conserve1:0.02186819,Loss_conserve3:0.08212537, Loss_pde:2.78458500
# epoch:12200, loss:0.00333692, Loss_conserve1:0.02233614,Loss_conserve3:0.08521585, Loss_pde:2.75451422
# epoch:12300, loss:0.00329150, Loss_conserve1:0.02225638,Loss_conserve3:0.08635410, Loss_pde:2.64461088
# epoch:12400, loss:0.00415118, Loss_conserve1:0.02211102,Loss_conserve3:0.08296362, Loss_pde:2.76510620
# epoch:12500, loss:0.00328074, Loss_conserve1:0.02184873,Loss_conserve3:0.08349174, Loss_pde:2.67485070
# epoch:12600, loss:0.00402754, Loss_conserve1:0.02178012,Loss_conserve3:0.08237810, Loss_pde:2.81543541
# epoch:12700, loss:0.00471827, Loss_conserve1:0.02217800,Loss_conserve3:0.08806488, Loss_pde:2.55494642
# epoch:12800, loss:0.00390280, Loss_conserve1:0.02216680,Loss_conserve3:0.08330280, Loss_pde:2.71794605
# epoch:12900, loss:0.00352550, Loss_conserve1:0.02218648,Loss_conserve3:0.08427504, Loss_pde:2.59349394
# epoch:13000, loss:0.00311270, Loss_conserve1:0.02213083,Loss_conserve3:0.08427584, Loss_pde:2.52977085
# epoch:13100, loss:0.00389989, Loss_conserve1:0.02206874,Loss_conserve3:0.08316493, Loss_pde:2.72499657
# epoch:13200, loss:0.00313678, Loss_conserve1:0.02236030,Loss_conserve3:0.08562840, Loss_pde:2.63451743
# epoch:13300, loss:0.00316514, Loss_conserve1:0.02233610,Loss_conserve3:0.08507480, Loss_pde:2.65569925
# epoch:13400, loss:0.00304883, Loss_conserve1:0.02264858,Loss_conserve3:0.08721720, Loss_pde:2.54913068
# epoch:13500, loss:0.00294180, Loss_conserve1:0.02201005,Loss_conserve3:0.08522132, Loss_pde:2.39219379
# epoch:13600, loss:0.00300056, Loss_conserve1:0.02227972,Loss_conserve3:0.08536164, Loss_pde:2.45515728
# epoch:13700, loss:0.00327048, Loss_conserve1:0.02216399,Loss_conserve3:0.08647554, Loss_pde:2.40107489
# epoch:13800, loss:0.00335925, Loss_conserve1:0.02224930,Loss_conserve3:0.08698492, Loss_pde:2.42677641
# epoch:13900, loss:0.00292649, Loss_conserve1:0.02235775,Loss_conserve3:0.08591736, Loss_pde:2.41245365
# epoch:14000, loss:0.00351187, Loss_conserve1:0.02237899,Loss_conserve3:0.08732372, Loss_pde:2.43844604
# epoch:14100, loss:0.00316905, Loss_conserve1:0.02272135,Loss_conserve3:0.08580062, Loss_pde:2.55404615
# epoch:14200, loss:0.00301829, Loss_conserve1:0.02219403,Loss_conserve3:0.08448970, Loss_pde:2.41565466
# epoch:14300, loss:0.00293585, Loss_conserve1:0.02234240,Loss_conserve3:0.08504274, Loss_pde:2.41044044
# epoch:14400, loss:0.00343193, Loss_conserve1:0.02255759,Loss_conserve3:0.08486617, Loss_pde:2.53528762
# epoch:14500, loss:0.00280149, Loss_conserve1:0.02246756,Loss_conserve3:0.08629761, Loss_pde:2.37602592
# epoch:14600, loss:0.00288190, Loss_conserve1:0.02268879,Loss_conserve3:0.08621050, Loss_pde:2.48228645
# epoch:14700, loss:0.00436986, Loss_conserve1:0.02200612,Loss_conserve3:0.08306514, Loss_pde:2.43874168
# epoch:14800, loss:0.00348801, Loss_conserve1:0.02235386,Loss_conserve3:0.08769916, Loss_pde:2.31128359
# epoch:14900, loss:0.00332968, Loss_conserve1:0.02267709,Loss_conserve3:0.08798150, Loss_pde:2.19844151
# epoch:15000, loss:0.00320158, Loss_conserve1:0.02259744,Loss_conserve3:0.08542296, Loss_pde:2.50426006
# epoch:15100, loss:0.00288903, Loss_conserve1:0.02270235,Loss_conserve3:0.08693571, Loss_pde:2.49562645
# epoch:15200, loss:0.00371142, Loss_conserve1:0.02258888,Loss_conserve3:0.08925583, Loss_pde:2.17632484
# epoch:15300, loss:0.00325619, Loss_conserve1:0.02259045,Loss_conserve3:0.08547513, Loss_pde:2.52598166
# epoch:15400, loss:0.00300904, Loss_conserve1:0.02289695,Loss_conserve3:0.08914061, Loss_pde:2.40165424
# epoch:15500, loss:0.00278617, Loss_conserve1:0.02245937,Loss_conserve3:0.08611299, Loss_pde:2.41246223
# epoch:15600, loss:0.00284025, Loss_conserve1:0.02276653,Loss_conserve3:0.08768712, Loss_pde:2.42173815
# epoch:15700, loss:0.00280940, Loss_conserve1:0.02292069,Loss_conserve3:0.08848734, Loss_pde:2.38578081
# epoch:15800, loss:0.00289871, Loss_conserve1:0.02255882,Loss_conserve3:0.08753289, Loss_pde:2.25694132
# epoch:15900, loss:0.00340595, Loss_conserve1:0.02236477,Loss_conserve3:0.08479852, Loss_pde:2.57495022
# epoch:16000, loss:0.00287536, Loss_conserve1:0.02253242,Loss_conserve3:0.08665556, Loss_pde:2.45539045
# epoch:16100, loss:0.00426218, Loss_conserve1:0.02223967,Loss_conserve3:0.08358797, Loss_pde:2.43631077
# epoch:16200, loss:0.00307206, Loss_conserve1:0.02280757,Loss_conserve3:0.08608301, Loss_pde:2.40535545
# epoch:16300, loss:0.00301381, Loss_conserve1:0.02287356,Loss_conserve3:0.08798273, Loss_pde:2.38662958
# epoch:16400, loss:0.00329627, Loss_conserve1:0.02254853,Loss_conserve3:0.08849557, Loss_pde:2.17780447
# epoch:16500, loss:0.00329129, Loss_conserve1:0.02263058,Loss_conserve3:0.08533360, Loss_pde:2.43470383
# epoch:16600, loss:0.00281774, Loss_conserve1:0.02293065,Loss_conserve3:0.08691011, Loss_pde:2.35728478
# epoch:16700, loss:0.00294162, Loss_conserve1:0.02285431,Loss_conserve3:0.08809352, Loss_pde:2.15628481
# epoch:16800, loss:0.00294797, Loss_conserve1:0.02270798,Loss_conserve3:0.08815531, Loss_pde:2.04722166
# epoch:16900, loss:0.00287919, Loss_conserve1:0.02292098,Loss_conserve3:0.08700293, Loss_pde:2.39797306
# epoch:17000, loss:0.00280256, Loss_conserve1:0.02276061,Loss_conserve3:0.08692332, Loss_pde:2.41454411
# epoch:17100, loss:0.00267756, Loss_conserve1:0.02268264,Loss_conserve3:0.08712605, Loss_pde:2.28485250
# epoch:17200, loss:0.00382929, Loss_conserve1:0.02284642,Loss_conserve3:0.08969282, Loss_pde:2.25351381
# epoch:17300, loss:0.00361946, Loss_conserve1:0.02271762,Loss_conserve3:0.08525738, Loss_pde:2.34728289
# epoch:17400, loss:0.00368200, Loss_conserve1:0.02269275,Loss_conserve3:0.09003603, Loss_pde:2.18641663
# epoch:17500, loss:0.00328818, Loss_conserve1:0.02254363,Loss_conserve3:0.08525888, Loss_pde:2.43895650
# epoch:17600, loss:0.00266195, Loss_conserve1:0.02264219,Loss_conserve3:0.08625096, Loss_pde:2.23467827
# epoch:17700, loss:0.00271068, Loss_conserve1:0.02290957,Loss_conserve3:0.08831427, Loss_pde:2.13978624
# epoch:17800, loss:0.00267541, Loss_conserve1:0.02308807,Loss_conserve3:0.08801873, Loss_pde:2.27397966
# epoch:17900, loss:0.00290699, Loss_conserve1:0.02271461,Loss_conserve3:0.08825726, Loss_pde:2.21083879
# epoch:18000, loss:0.00264862, Loss_conserve1:0.02297964,Loss_conserve3:0.08750333, Loss_pde:2.26961899
# epoch:18100, loss:0.00289034, Loss_conserve1:0.02289754,Loss_conserve3:0.08660306, Loss_pde:2.32562017
# epoch:18200, loss:0.00333654, Loss_conserve1:0.02323031,Loss_conserve3:0.09041075, Loss_pde:2.22982216
# epoch:18300, loss:0.00262221, Loss_conserve1:0.02249156,Loss_conserve3:0.08613809, Loss_pde:2.17790270
# epoch:18400, loss:0.00276131, Loss_conserve1:0.02254861,Loss_conserve3:0.08719448, Loss_pde:2.17297554
# epoch:18500, loss:0.00277881, Loss_conserve1:0.02272400,Loss_conserve3:0.08821601, Loss_pde:2.17021799
# epoch:18600, loss:0.00261576, Loss_conserve1:0.02270880,Loss_conserve3:0.08770992, Loss_pde:2.10868883
# epoch:18700, loss:0.00259664, Loss_conserve1:0.02306389,Loss_conserve3:0.08762006, Loss_pde:2.17207360
# epoch:18800, loss:0.00304227, Loss_conserve1:0.02295215,Loss_conserve3:0.08645126, Loss_pde:2.24908352
# epoch:18900, loss:0.00263597, Loss_conserve1:0.02307657,Loss_conserve3:0.08811489, Loss_pde:2.24184179
# epoch:19000, loss:0.00263315, Loss_conserve1:0.02269174,Loss_conserve3:0.08751753, Loss_pde:2.19594836
# epoch:19100, loss:0.00269831, Loss_conserve1:0.02273201,Loss_conserve3:0.08700733, Loss_pde:2.25474548
# epoch:19200, loss:0.00330962, Loss_conserve1:0.02256091,Loss_conserve3:0.08523589, Loss_pde:2.36531162
# epoch:19300, loss:0.00255928, Loss_conserve1:0.02260673,Loss_conserve3:0.08651502, Loss_pde:2.18194485
# epoch:19400, loss:0.00245504, Loss_conserve1:0.02274017,Loss_conserve3:0.08712142, Loss_pde:2.09129763
# epoch:19500, loss:0.00289949, Loss_conserve1:0.02293182,Loss_conserve3:0.09006575, Loss_pde:2.10882187
# epoch:19600, loss:0.00248042, Loss_conserve1:0.02296894,Loss_conserve3:0.08781730, Loss_pde:2.06620646
# epoch:19700, loss:0.00268061, Loss_conserve1:0.02323527,Loss_conserve3:0.08896139, Loss_pde:2.20241022
# epoch:19800, loss:0.00257726, Loss_conserve1:0.02310336,Loss_conserve3:0.08841212, Loss_pde:2.22406816
# epoch:19900, loss:0.00277351, Loss_conserve1:0.02332713,Loss_conserve3:0.09024189, Loss_pde:2.15599632
# epoch:20000, loss:0.00277093, Loss_conserve1:0.02299275,Loss_conserve3:0.08718760, Loss_pde:2.22073030
# epoch:20100, loss:0.00268010, Loss_conserve1:0.02284130,Loss_conserve3:0.08804329, Loss_pde:2.06107807
# epoch:20200, loss:0.00253075, Loss_conserve1:0.02279203,Loss_conserve3:0.08779351, Loss_pde:2.21781969
# epoch:20300, loss:0.00258181, Loss_conserve1:0.02287437,Loss_conserve3:0.08717538, Loss_pde:2.13381147
# epoch:20400, loss:0.00320576, Loss_conserve1:0.02316309,Loss_conserve3:0.09175709, Loss_pde:2.05945539
# epoch:20500, loss:0.00348139, Loss_conserve1:0.02266816,Loss_conserve3:0.08539451, Loss_pde:2.17979193
# epoch:20600, loss:0.00257927, Loss_conserve1:0.02286804,Loss_conserve3:0.08838481, Loss_pde:2.14224100
# epoch:20700, loss:0.00295960, Loss_conserve1:0.02292112,Loss_conserve3:0.08651416, Loss_pde:2.21516371
# epoch:20800, loss:0.00402755, Loss_conserve1:0.02248708,Loss_conserve3:0.08518513, Loss_pde:2.16862869
# epoch:20900, loss:0.00258209, Loss_conserve1:0.02278512,Loss_conserve3:0.08742551, Loss_pde:2.13429117
# epoch:21000, loss:0.00263169, Loss_conserve1:0.02303933,Loss_conserve3:0.08736089, Loss_pde:2.19603157
# epoch:21100, loss:0.00291797, Loss_conserve1:0.02309884,Loss_conserve3:0.08734929, Loss_pde:2.17369914
# epoch:21200, loss:0.00248800, Loss_conserve1:0.02304316,Loss_conserve3:0.08773591, Loss_pde:2.11966848
# epoch:21300, loss:0.00236941, Loss_conserve1:0.02297216,Loss_conserve3:0.08806282, Loss_pde:2.06355858
# epoch:21400, loss:0.00299544, Loss_conserve1:0.02290047,Loss_conserve3:0.08671442, Loss_pde:2.20959854
# epoch:21500, loss:0.00290292, Loss_conserve1:0.02302035,Loss_conserve3:0.08930503, Loss_pde:1.97281718
# epoch:21600, loss:0.00268889, Loss_conserve1:0.02309010,Loss_conserve3:0.08946081, Loss_pde:2.03121948
# epoch:21700, loss:0.00330252, Loss_conserve1:0.02270130,Loss_conserve3:0.08559091, Loss_pde:2.12289429
# epoch:21800, loss:0.00284672, Loss_conserve1:0.02296198,Loss_conserve3:0.08672187, Loss_pde:2.16554308
# epoch:21900, loss:0.00307390, Loss_conserve1:0.02281344,Loss_conserve3:0.08619188, Loss_pde:2.23404980
# epoch:22000, loss:0.00264731, Loss_conserve1:0.02305761,Loss_conserve3:0.08982642, Loss_pde:2.02824521
# epoch:22100, loss:0.00261445, Loss_conserve1:0.02290817,Loss_conserve3:0.08901785, Loss_pde:2.05029631
# epoch:22200, loss:0.00254259, Loss_conserve1:0.02331542,Loss_conserve3:0.08877331, Loss_pde:2.18988824
# epoch:22300, loss:0.00306442, Loss_conserve1:0.02333680,Loss_conserve3:0.09108153, Loss_pde:2.04653239
# epoch:22400, loss:0.00240736, Loss_conserve1:0.02273058,Loss_conserve3:0.08692911, Loss_pde:2.02997208
# epoch:22500, loss:0.00286029, Loss_conserve1:0.02297225,Loss_conserve3:0.08682523, Loss_pde:2.16063976
# epoch:22600, loss:0.00311981, Loss_conserve1:0.02306014,Loss_conserve3:0.08710355, Loss_pde:2.11181045
# epoch:22700, loss:0.00302904, Loss_conserve1:0.02296333,Loss_conserve3:0.08655720, Loss_pde:2.11995029
# epoch:22800, loss:0.00255642, Loss_conserve1:0.02293664,Loss_conserve3:0.08731884, Loss_pde:2.16073513
# epoch:22900, loss:0.00248146, Loss_conserve1:0.02278176,Loss_conserve3:0.08764833, Loss_pde:2.07636070
# epoch:23000, loss:0.00258119, Loss_conserve1:0.02274286,Loss_conserve3:0.08837022, Loss_pde:1.97146571
# epoch:23100, loss:0.00280922, Loss_conserve1:0.02307800,Loss_conserve3:0.08715008, Loss_pde:2.11797786
# epoch:23200, loss:0.00331574, Loss_conserve1:0.02275436,Loss_conserve3:0.08602270, Loss_pde:2.10323811
# epoch:23300, loss:0.00236194, Loss_conserve1:0.02296088,Loss_conserve3:0.08846717, Loss_pde:2.03332043
# epoch:23400, loss:0.00259260, Loss_conserve1:0.02297483,Loss_conserve3:0.08770464, Loss_pde:2.20768595
# epoch:23500, loss:0.00246163, Loss_conserve1:0.02335796,Loss_conserve3:0.08839043, Loss_pde:2.01509953
# epoch:23600, loss:0.00326217, Loss_conserve1:0.02271412,Loss_conserve3:0.08581346, Loss_pde:2.25205421
# epoch:23700, loss:0.00233090, Loss_conserve1:0.02317679,Loss_conserve3:0.08879093, Loss_pde:1.96141386
# epoch:23800, loss:0.00312882, Loss_conserve1:0.02337225,Loss_conserve3:0.09099153, Loss_pde:1.95710588
# epoch:23900, loss:0.00264579, Loss_conserve1:0.02326131,Loss_conserve3:0.08816076, Loss_pde:2.11841726
# epoch:24000, loss:0.00227999, Loss_conserve1:0.02292505,Loss_conserve3:0.08789983, Loss_pde:1.98695993
# epoch:24100, loss:0.00287421, Loss_conserve1:0.02287979,Loss_conserve3:0.08622158, Loss_pde:2.09397173
# epoch:24200, loss:0.00296693, Loss_conserve1:0.02282744,Loss_conserve3:0.08913622, Loss_pde:1.93506241
# epoch:24300, loss:0.00280081, Loss_conserve1:0.02352360,Loss_conserve3:0.09086929, Loss_pde:2.01648235
# epoch:24400, loss:0.00333609, Loss_conserve1:0.02318534,Loss_conserve3:0.09140666, Loss_pde:2.03241873
# epoch:24500, loss:0.00272909, Loss_conserve1:0.02297417,Loss_conserve3:0.08680566, Loss_pde:2.05272269
# epoch:24600, loss:0.00229018, Loss_conserve1:0.02318791,Loss_conserve3:0.08827905, Loss_pde:1.91581988
# epoch:24700, loss:0.00267386, Loss_conserve1:0.02312188,Loss_conserve3:0.08731495, Loss_pde:2.03515124
# epoch:24800, loss:0.00269707, Loss_conserve1:0.02366163,Loss_conserve3:0.09103049, Loss_pde:2.05822229
# epoch:24900, loss:0.00294733, Loss_conserve1:0.02279410,Loss_conserve3:0.08643265, Loss_pde:2.19049287
# epoch:25000, loss:0.00238754, Loss_conserve1:0.02352587,Loss_conserve3:0.09003036, Loss_pde:2.03017569
# epoch:25100, loss:0.00333431, Loss_conserve1:0.02320758,Loss_conserve3:0.09112999, Loss_pde:1.94594622
# epoch:25200, loss:0.00250603, Loss_conserve1:0.02300231,Loss_conserve3:0.08769298, Loss_pde:2.12203836
# epoch:25300, loss:0.00237255, Loss_conserve1:0.02318987,Loss_conserve3:0.08832198, Loss_pde:2.03675222
# epoch:25400, loss:0.00217500, Loss_conserve1:0.02345973,Loss_conserve3:0.08997498, Loss_pde:1.77910376
# epoch:25500, loss:0.00258967, Loss_conserve1:0.02297531,Loss_conserve3:0.08910672, Loss_pde:1.97163367
# epoch:25600, loss:0.00302729, Loss_conserve1:0.02267315,Loss_conserve3:0.08605190, Loss_pde:2.24239564
# epoch:25700, loss:0.00305506, Loss_conserve1:0.02276586,Loss_conserve3:0.08594932, Loss_pde:2.13469982
# epoch:25800, loss:0.00228604, Loss_conserve1:0.02324390,Loss_conserve3:0.08839391, Loss_pde:1.96424294
# epoch:25900, loss:0.00328578, Loss_conserve1:0.02293441,Loss_conserve3:0.08644689, Loss_pde:2.03947496
# epoch:26000, loss:0.00251233, Loss_conserve1:0.02319028,Loss_conserve3:0.08747546, Loss_pde:1.94012725
# epoch:26100, loss:0.00227526, Loss_conserve1:0.02309359,Loss_conserve3:0.08829895, Loss_pde:1.99226630
# epoch:26200, loss:0.00220724, Loss_conserve1:0.02285113,Loss_conserve3:0.08796521, Loss_pde:1.85118985
# epoch:26300, loss:0.00243170, Loss_conserve1:0.02346186,Loss_conserve3:0.08982147, Loss_pde:2.10374498
# epoch:26400, loss:0.00275275, Loss_conserve1:0.02295870,Loss_conserve3:0.08718903, Loss_pde:2.21784401
# epoch:26500, loss:0.00235770, Loss_conserve1:0.02349697,Loss_conserve3:0.08915363, Loss_pde:1.98241735
# epoch:26600, loss:0.00227908, Loss_conserve1:0.02347542,Loss_conserve3:0.09013799, Loss_pde:1.90113091
# epoch:26700, loss:0.00222988, Loss_conserve1:0.02324189,Loss_conserve3:0.08910228, Loss_pde:1.86135650
# epoch:26800, loss:0.00238654, Loss_conserve1:0.02338677,Loss_conserve3:0.08876606, Loss_pde:2.06538320
# epoch:26900, loss:0.00223276, Loss_conserve1:0.02339690,Loss_conserve3:0.08913673, Loss_pde:1.98492646
# epoch:27000, loss:0.00269902, Loss_conserve1:0.02293503,Loss_conserve3:0.08728838, Loss_pde:2.21671367
# epoch:27100, loss:0.00238276, Loss_conserve1:0.02295945,Loss_conserve3:0.08822995, Loss_pde:2.04435039
# epoch:27200, loss:0.00358327, Loss_conserve1:0.02273927,Loss_conserve3:0.08605337, Loss_pde:2.00896764
# epoch:27300, loss:0.00229420, Loss_conserve1:0.02348032,Loss_conserve3:0.08961061, Loss_pde:1.98187041
# epoch:27400, loss:0.00226314, Loss_conserve1:0.02332771,Loss_conserve3:0.08925678, Loss_pde:1.94178236
# epoch:27500, loss:0.00216499, Loss_conserve1:0.02349617,Loss_conserve3:0.08920766, Loss_pde:1.85053873
# epoch:27600, loss:0.00256034, Loss_conserve1:0.02300010,Loss_conserve3:0.08903793, Loss_pde:1.93581402
# epoch:27700, loss:0.00249481, Loss_conserve1:0.02335149,Loss_conserve3:0.09055760, Loss_pde:1.85520720
# epoch:27800, loss:0.00242618, Loss_conserve1:0.02321418,Loss_conserve3:0.08810496, Loss_pde:2.02089930
# epoch:27900, loss:0.00234486, Loss_conserve1:0.02326549,Loss_conserve3:0.08829136, Loss_pde:1.98721361
# epoch:28000, loss:0.00235607, Loss_conserve1:0.02357637,Loss_conserve3:0.08973420, Loss_pde:2.05060768
# epoch:28100, loss:0.00293781, Loss_conserve1:0.02300906,Loss_conserve3:0.08971216, Loss_pde:1.95071912
# epoch:28200, loss:0.00236373, Loss_conserve1:0.02307590,Loss_conserve3:0.08805177, Loss_pde:2.04471517
# epoch:28300, loss:0.00238562, Loss_conserve1:0.02344694,Loss_conserve3:0.08887778, Loss_pde:1.96929610
# epoch:28400, loss:0.00248442, Loss_conserve1:0.02316912,Loss_conserve3:0.08749468, Loss_pde:2.00105810
# epoch:28500, loss:0.00222525, Loss_conserve1:0.02315517,Loss_conserve3:0.08839800, Loss_pde:1.92097855
# epoch:28600, loss:0.00222442, Loss_conserve1:0.02315521,Loss_conserve3:0.08889613, Loss_pde:1.92744136
# epoch:28700, loss:0.00332324, Loss_conserve1:0.02325416,Loss_conserve3:0.09134887, Loss_pde:1.89631939
# epoch:28800, loss:0.00228804, Loss_conserve1:0.02307642,Loss_conserve3:0.08877165, Loss_pde:1.94969583
# epoch:28900, loss:0.00247192, Loss_conserve1:0.02338660,Loss_conserve3:0.09075072, Loss_pde:1.72739983
# epoch:29000, loss:0.00222292, Loss_conserve1:0.02330901,Loss_conserve3:0.08842862, Loss_pde:1.95645869
# epoch:29100, loss:0.00225674, Loss_conserve1:0.02296672,Loss_conserve3:0.08829071, Loss_pde:1.90120959
# epoch:29200, loss:0.00201227, Loss_conserve1:0.02322927,Loss_conserve3:0.08923383, Loss_pde:1.72905695
# epoch:29300, loss:0.00220715, Loss_conserve1:0.02322989,Loss_conserve3:0.08903386, Loss_pde:1.89089620
# epoch:29400, loss:0.00226991, Loss_conserve1:0.02288050,Loss_conserve3:0.08786891, Loss_pde:1.86598039
# epoch:29500, loss:0.00240209, Loss_conserve1:0.02371443,Loss_conserve3:0.09086528, Loss_pde:1.97272635
# epoch:29600, loss:0.00228193, Loss_conserve1:0.02328657,Loss_conserve3:0.08952098, Loss_pde:1.64739537
# epoch:29700, loss:0.00264456, Loss_conserve1:0.02353323,Loss_conserve3:0.09142812, Loss_pde:1.85710919
# epoch:29800, loss:0.00225179, Loss_conserve1:0.02333549,Loss_conserve3:0.08853649, Loss_pde:1.93957520
# epoch:29900, loss:0.00221427, Loss_conserve1:0.02343127,Loss_conserve3:0.08934832, Loss_pde:1.88655448

# %% [markdown]
# ## loss curve
# ## total time need to train

# %%
#plot


X = np.hstack((x.flatten()[:, None], t.flatten()[:, None]))
X_tensor = torch.from_numpy(X).float().to(device)

R_pred = Net.forward(X_tensor)[:, 0:1] # if use GPU
R_pred1 = R_pred.detach().cpu().numpy().reshape(N, N)

M_pred = Net.forward(X_tensor)[:, 1:2] # if use GPU
M_pred1 = M_pred.detach().cpu().numpy().reshape(N, N)



from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8,6))
ax = plt.axes(projection='3d')
ax.plot_surface(x, t, np.sqrt(R_pred1**2 + M_pred1**2), cmap="viridis")
ax.set_xlabel('$x$')
ax.set_ylabel('$t$')
ax.set_zlabel('$U(x,t)$')
plt.savefig("datadriven_dark_3d_fle.pdf", dpi='figure', transparent = True)
plt.show()


fig = plt.figure(figsize=(8,6))
ax = plt.axes(projection='3d')
ax.plot_surface(x, t, np.sqrt(r**2 + m**2), cmap="viridis")
ax.set_xlabel('$x$')
ax.set_ylabel('$t$')
ax.set_zlabel('$U(x,t)$')
plt.savefig("exact_dark_3d_fle.pdf", dpi='figure', transparent = True)
plt.show()

# %%
plt.pcolor(x, t, np.sqrt(R_pred1**2 + M_pred1**2), cmap="viridis")
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.title("predicted")
plt.colorbar()
plt.savefig("density_datadriven_dark_fle.pdf", dpi='figure', transparent = True)
plt.show()

plt.pcolor(x, t, np.sqrt(r**2 + m**2), cmap="viridis")
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.title("exact")
plt.colorbar()
plt.savefig("density_exact_dark_fle.pdf", dpi='figure', transparent = True)
plt.show()

error = np.sqrt(R_pred1**2 + M_pred1**2) - np.sqrt(r**2 + m**2)
plt.pcolor(x, t, error, cmap="viridis")
plt.xlabel('$x$')
plt.ylabel('$t$')
plt.title("error")
plt.colorbar()
plt.savefig("error_dark_fle.pdf", dpi='figure', transparent = True)
plt.show()

# %%
U_predicted= np.sqrt(R_pred1**2 + M_pred1**2)
for ml in range(0 , N, 10):
  plt.plot(x_space, U_predicted[ml, :])
  plt.xlabel("x")
  plt.ylabel("|U|")
  print((  (x_space[-1]- x_space[0] )/N ) * np.sum(U_predicted[ml, :]**2))
# Out:
# 7.617244873046875
# 7.6185009765625
# 7.619119873046875
# 7.6217279052734375
# 7.6227966308593755
# 7.618650512695313
# 7.612896118164063
# 7.605247802734375
# 7.593673095703125
# 7.579224853515625

# %%
for mk in range(0 , N, 10):
  plt.plot(x_space, UU[mk, :])
  plt.xlabel("x")
  plt.ylabel("U")
  print((  (x_space[-1]- x_space[0] )/N ) * np.sum(UU[mk, :]**2))
# Out:
# 7.593797058537728
# 7.593795223633706
# 7.593793819215652
# 7.59379279418798
# 7.593792111257508
# 7.593791745577171
# 7.593791683842327
# 7.5937919238068545
# 7.593792474201461
# 7.593793355051219

# %%
plt.plot(x_space, UU[85,:], 'b-', linewidth = 2, label = 'Exact')
plt.plot(x_space, U_predicted[85,:], 'r--', linewidth = 2, label = 'Prediction')
plt.xlabel('$x$')
plt.ylabel('$|u(t,x)|$')
plt.title('$t = %.2f$' % (t_space[85]), fontsize = 10)
plt.legend()
plt.savefig("compare11_dark_conserve.pdf", dpi='figure', transparent = True)
plt.show()

plt.plot(x_space, UU[35,:], 'b-', linewidth = 2, label = 'Exact')
plt.plot(x_space, U_predicted[35,:], 'r--', linewidth = 2, label = 'Prediction')
plt.xlabel('$x$')
plt.ylabel('$|u(t,x)|$')
plt.title('$t = %.2f$' % (t_space[35]), fontsize = 10)
plt.legend()
plt.savefig("compare22_dark_conserve.pdf", dpi='figure', transparent = True)
plt.show()


plt.plot(x_space, UU[15,:], 'b-', linewidth = 2, label = 'Exact')
plt.plot(x_space, U_predicted[15,:], 'r--', linewidth = 2, label = 'Prediction')
plt.xlabel('$x$')
plt.ylabel('$|u(t,x)|$')
plt.title('$t = %.2f$' % (t_space[15]), fontsize = 10)
plt.legend()
plt.savefig("compare33_dark_conserve.pdf", dpi='figure', transparent = True)
plt.show()
